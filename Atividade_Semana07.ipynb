# %% [markdown]
# # Atividade - Semana 07 - Visualizando Dados
#
# Esta é atividade semanal sugerida. Você deverá preenchê-la e enviá-la dentro do prazo (até o fechamento da semana corrente).

# %% [markdown]
# ###Questão 1
#
# Crie um gráfico de linha para a expectativa de vida (em anos) da população brasileira:
#   -  Adicione um título;
#   -  Adicione rótulos nos eixos;
#   -  Use o estilo como desejar (cor, marcador, estilo da linha, etc...);
#   -  Ao fim, exiba o gráfico usando `plt.show()`.

# %%
# Questao 1

from matplotlib import pyplot as plt

anos = [1940, 1950, 1960, 1970, 1980, 1991, 2000, 2010, 2018, 2019, 2020]
expectativa_vida = [45.5, 48, 52.5, 57.6, 62.5, 66.9, 69.8, 73.9, 76.3, 76.6, 76.8]

plt.plot(anos, expectativa_vida, color = "Red", marker= 'o', linestyle = 'solid')

plt.title("Expectativa de Vida(anos) dos Brasileiros")

plt.ylabel("Anos")

plt.show()

# %% [markdown]
# ###Questão 2
#
# Crie um gráfico de barras para o número de temporadas das séries de TV mais longínquas:
#   -  Adicione um título;
#   -  Adicione rótulos nos eixos;
#   -  Use o estilo como desejar (cor, estilo da linha, etc...);
#   -  Ao fim, exiba o gráfico usando `plt.show()`.

# %%
# Questao 2

series = ["Os Simpsons", "Lei e Ordem: SVU", "Lei e Ordem", "Família da Pesada"]
temporadas = [34, 24, 22, 21]

plt.bar(series, temporadas, linestyle = '--', edgecolor= 'black' , color = "peachpuff")
plt.xticks(rotation = 10)

plt.title("N° de temporadas de séries mais longíquas")
plt.ylabel("N° de Temporadas")

plt.show()

# %% [markdown]
# ###Questão 3
#
# Abaixo temos a altura dos jogadores da seleção brasileira de futebol que participaram da Copa do Mundo 2022. Crie um histograma para a altura destes jogadores.
#
#   -  Adicione um título;
#   -  Adicione rótulos nos eixos;
#   -  Use o estilo como desejar (cor, estilo da linha, etc...);
#   -  Ao fim, exiba o gráfico usando `plt.show()`.

# %%
# Questao 3

altura = [1.93, 1.88, 1.88, 1.83, 1.83, 1.83, 1.8, 1.73, 1.85, 1.8, 1.88, 1.85,
          1.8, 1.7, 1.88, 1.83, 1.7, 1.83, 1.75, 1.75, 1.75, 1.75, 1.75, 1.75,
          1.85, 1.78]
plt.hist(altura, 6, edgecolor= "black")
plt.title("Altura dos jogadores da seleção brasileira copa 2022")

plt.ylabel("número de jogadores com as respectitivas alturas")
plt.show()

# %% [markdown]
# ###Questão 4
#
# Escolha uma das ações disponíveis e crie um gráfico de linha ao longo do tempo:
#   -  Adicione um título;
#   -  Adicione rótulos nos eixos;
#   -  Use o estilo como desejar (cor, estilo da linha, etc...);
#   -  Ao fim, exiba o gráfico usando `plt.show()`.

# %%
# Questao 4

# %pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\edson\anaconda3\lib\site-packages (0.2.50)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\edson\anaconda3\lib\site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\edson\anaconda3\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\users\edson\anaconda3\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\edson\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\edson\anaconda3\lib\site-packages (from yfinance) (5.2.1)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\edson\anaconda3\lib\site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\edson\anaconda3\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\edson\anaconda3\lib\site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\edson\anaconda3\lib\site-packages (from yfinance) (3.17.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\edson\anaconda3\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in c:\users\edson\anaconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\edson\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in c:\users\edson\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\edson\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\edson\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\edson\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\edson\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\edson\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\edson\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\edson\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf

# OPCOES:
# B3SA3.SA: B3 S.A. - Brasil, Bolsa, Balcão
# BBAS3.SA: Banco do Brasil S.A.
# EMBR3.SA: Centrais Elétricas Brasileiras S.A. - Eletrobrás
# EMBR3.SA: Embraer S.A.
# PETR4.SA: Petróleo Brasileiro S.A. - Petrobras
acoes = yf.download("B3SA3.SA",  # Por exemplo: "B3SA3.SA"
                    start = "2023-12-01",    # Por exemplo: 2022-12-01
                    end = "2024-03-18")      # Por exemplo: 2023-03-18

# separando somente os valores de fechamento
acoes = acoes.loc[:, "Close"]

# renomeando
acoes.index.name = 'data'

ax = acoes.plot()

ax.set_xlabel("Data")
ax.set_ylabel("Valor (R$)")
ax.set_title("Valores de fechamento em 2024.")
# Out:
# [*********************100%***********************]  1 of 1 completed
# Text(0.5, 1.0, 'Valores de fechamento em 2024.')
