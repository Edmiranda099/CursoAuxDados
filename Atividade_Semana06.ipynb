# %% [markdown]
# # Atividade - Semana 06 - Trabalhando com dados
#
# Esta é atividade semanal sugerida. Você deverá preenchê-la e enviá-la dentro do prazo (até o fechamento da semana corrente).

# %% [markdown]
# ###Questão 1
#
# Importe a planilha `dados_starwars.xlsx` na pasta virtual `content`.

# %%
# Questao 1

import pandas as pd

caminho = "dados_starwars.xlsx"

dados_starwars = pd.read_excel(caminho)

dados_starwars
# Out:
#               nome  altura  massa cor_do_cabelo   cor_da_pele     genero  \
# 0   Luke Skywalker   172.0   77.0         Loiro  Branca clara  Masculino
# 1            C-3PO   167.0   75.0           NaN          Ouro  Masculino
# 2            R2-D2    96.0   32.0           NaN  Branca, Azul  Masculino
# 3      Darth Vader   202.0  136.0        Nenhum        Branca  Masculino
# 4      Leia Organa   150.0   49.0      Castanho         Clara   Feminino
# ..             ...     ...    ...           ...           ...        ...
# 82             Rey     NaN    NaN      Castanho         Clara   Feminino
# 83     Poe Dameron     NaN    NaN      Castanho         Clara  Masculino
# 84             BB8     NaN    NaN        Nenhum       Nenhuma  Masculino
# 85  Captain Phasma     NaN    NaN  Desconhecido  Desconhecida        NaN
# 86  PadmÃ© Amidala   165.0   45.0      Castanho         Clara   Feminino
#
#    planeta_natal especie
# 0       Tatooine  Humano
# 1       Tatooine  Droide
# ...

# %% [markdown]
# ###Questão 2
#
# Remova todos os valores faltantes. Salve a base de dados atualizada.

# %%
# Questao 2
dados_starwars = dados_starwars.dropna()
dados_starwars
# Out:
#                      nome  altura  massa    cor_do_cabelo  \
# 0          Luke Skywalker   172.0   77.0            Loiro
# 3             Darth Vader   202.0  136.0           Nenhum
# 4             Leia Organa   150.0   49.0         Castanho
# 5               Owen Lars   178.0  120.0  Castanho, Cinza
# 6      Beru Whitesun lars   165.0   75.0         Castanho
# 8       Biggs Darklighter   183.0   84.0            Preto
# 9          Obi-Wan Kenobi   182.0   77.0    Ruivo, Branco
# 10       Anakin Skywalker   188.0   84.0            Loiro
# 12              Chewbacca   228.0  112.0         Castanho
# 13               Han Solo   180.0   80.0         Castanho
# 16         Wedge Antilles   170.0   77.0         Castanho
# 17       Jek Tono Porkins   180.0  110.0         Castanho
# 19              Palpatine   170.0   75.0            Cinza
# 20              Boba Fett   183.0   78.2            Preto
# 22                  Bossk   190.0  113.0           Nenhum
# ...

# %% [markdown]
# ###Questão 3
#
# Filtre somente os registros com `especie` = `humano`. Salve a base de dados atualizada.

# %%
# Questao 3
import pandas as pd

dados_starwars = pd.read_excel("dados_starwars.xlsx")

filtro_humano = dados_starwars[dados_starwars['especie'].str.lower() == 'humano']

# %% [markdown]
# ###Questão 4
#
# Edite a variável `altura` (que esta em centímetros) para que passe para a unidade em metros (*dividir por 100*). Salve a base de dados atualizada.

# %%
# Questao 4
import pandas as pd

dados_starwars = pd.read_excel("dados_starwars.xlsx")

dados_starwars["altura"] = dados_starwars["altura"]/100

# %% [markdown]
# ###Questão 5
#
# Renomeie a variável `altura` para `altura_metros`. Salve a base de dados atualizada.

# %%
# Questao 5
dados_starwars_alt = dados_starwars.rename(columns={'altura' : 'altura_metros'})
dados_starwars_alt.dropna()
# Out:
#                      nome  altura_metros  massa    cor_do_cabelo  \
# 0          Luke Skywalker           1.72   77.0            Loiro
# 3             Darth Vader           2.02  136.0           Nenhum
# 4             Leia Organa           1.50   49.0         Castanho
# 5               Owen Lars           1.78  120.0  Castanho, Cinza
# 6      Beru Whitesun lars           1.65   75.0         Castanho
# 8       Biggs Darklighter           1.83   84.0            Preto
# 9          Obi-Wan Kenobi           1.82   77.0    Ruivo, Branco
# 10       Anakin Skywalker           1.88   84.0            Loiro
# 12              Chewbacca           2.28  112.0         Castanho
# 13               Han Solo           1.80   80.0         Castanho
# 16         Wedge Antilles           1.70   77.0         Castanho
# 17       Jek Tono Porkins           1.80  110.0         Castanho
# 19              Palpatine           1.70   75.0            Cinza
# ...

# %% [markdown]
# ###Questão 6
#
# Ordene a base de dados por `altura_metros`. Salve a base de dados atualizada.

# %%
# Questao 6
import pandas as pd

dados_starwars = pd.read_excel("dados_starwars.xlsx")
dados_starwars_alt = dados_starwars.rename(columns={'altura' : 'altura_metros'})
dados_starwars_alt["altura_metros"] = dados_starwars_alt["altura_metros"]/100

dados_starwars_alt_sorted = dados_starwars_alt.sort_values(by= 'altura_metros' , ascending = False )
dados_starwars_alt_sorted.dropna()
# Out:
#                      nome  altura_metros  massa    cor_do_cabelo  \
# 77                Tarfful           2.34  136.0         Castanho
# 68                Lama Su           2.29   88.0           Nenhum
# 12              Chewbacca           2.28  112.0         Castanho
# 34           Roos Tarpals           2.24   82.0           Nenhum
# 76               Grievous           2.16  159.0           Nenhum
# 80             Tion Medon           2.06   80.0           Nenhum
# 3             Darth Vader           2.02  136.0           Nenhum
# 67        Dexter Jettster           1.98  102.0           Nenhum
# 48           Ki-Adi-Mundi           1.98   82.0           Branco
# 49              Kit Fisto           1.96   87.0           Nenhum
# 33          Jar Jar Binks           1.96   66.0           Nenhum
# 63                  Dooku           1.93   80.0           Branco
# 73             Wat Tambor           1.93   48.0           Nenhum
# ...

# %% [markdown]
# ###Questão 7
#
# Mantenha na base somente as variáveis: `nome`, `altura_metros`, `massa` e `genero`. Salve a base de dados atualizada.

# %%
# Questao 7
import pandas as pd

dados_starwars = pd.read_excel("dados_starwars.xlsx")
dados_starwars_alt = dados_starwars.rename(columns={'altura' : 'altura_metros'})

dados_starwars_alt = dados_starwars_alt.iloc[:,[0,1,2,5]]
dados_starwars_alt.dropna()
# Out:
#                      nome  altura_metros   massa     genero
# 0          Luke Skywalker          172.0    77.0  Masculino
# 1                   C-3PO          167.0    75.0  Masculino
# 2                   R2-D2           96.0    32.0  Masculino
# 3             Darth Vader          202.0   136.0  Masculino
# 4             Leia Organa          150.0    49.0   Feminino
# 5               Owen Lars          178.0   120.0  Masculino
# 6      Beru Whitesun lars          165.0    75.0   Feminino
# 7                   R5-D4           97.0    32.0  Masculino
# 8       Biggs Darklighter          183.0    84.0  Masculino
# 9          Obi-Wan Kenobi          182.0    77.0  Masculino
# 10       Anakin Skywalker          188.0    84.0  Masculino
# 12              Chewbacca          228.0   112.0  Masculino
# 13               Han Solo          180.0    80.0  Masculino
# 14                 Greedo          173.0    74.0  Masculino
# 15  Jabba Desilijic Tiure          175.0  1358.0  Masculino
# ...
